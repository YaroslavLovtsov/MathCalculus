# %% [markdown]
# __1.__ Найти производную $y'_{x}$ функции:
#
# ### $$\mbox{arctg}(\frac{y}{x})=\ln \sqrt{x^2+y^2}$$
#
# **Решение**
#
# $$\frac{\frac{xy'-y}{x^2}}{1+\frac{y^2}{x^2}} = \frac{2x + 2yy'}{2(x^2+y^2)},$$
#
# $$ xy'-y = x+ yy', $$
#
# $$ y'(x - y) = x + y, $$
#
# $$ y' = \frac{x+y}{x-y}$$

# %% [markdown]
# __2.__ Найти производную $y'_{x}$ функции:
#
# ### \begin{cases}
#    y=\frac{t^2}{t-1}, \\
#    x=\frac{t}{t^2-1}
#  \end{cases}
#
#  **Решение**
#
#  $$y'_x = \frac{\frac{2t(t-1)-t^2}{(t-1)^2}}{\frac{t^2-1-t \cdot 2t}{(t^2-1)^2}} = - \frac{(t^2-1)(t+1)^2}{t^2 + 1}$$

# %% [markdown]
# __3.__ Найти производную с помощью логарифмирования:
#
# ### $$y=(x^2+2)^5\cdot(3x-x^3)^3$$
#
# **Решение**
#
# $$ y' = (x^2+2)^5(3x - x^3)^3 \cdot (\frac{5 \cdot 2x}{x^2+2} + \frac{3 \cdot (3 - 3x^2)}{3x - x^3}) = (x^2+2)^4(3x - x^3)^2 \cdot (10x \cdot (3x-x^3) + 9(x^2+2)(1 - x^2)) = (x^2+2)^4(3x - x^3)^2 \cdot (2 + 21 x^2 - 19 x^4)$$

# %% [markdown]
# __4.__ Найти производную функции с помощью логарифмирования:
#
# ### $$y=x^x$$
#
# **Решение**
#
# $$y'=(x^x)' = (e^{x \cdot \ln x})' = (x \cdot \ln x)' x^x = (x \cdot \frac{1}{x} + \ln x) x^x = (1 + \ln x) x^x $$

# %% [markdown]
# __5.__ Найти производную функции с помощью логарифмирования:
#
# ### $$y=\frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x}$$
#
# Решение
#
# $$ \ln y = 3 \ln (2-x^2) + 2 \ln (x-1) - \ln x - \ln(2x^2-3) - x$$
#
# $$ y' = (\frac{3(-2x)}{2-x^2} + \frac{2}{x-1} -\frac{1}{x} - \frac{2 \cdot 2x}{2x^2-3}-1) \cdot \frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x} = $$
#
# $$ = (\frac{2}{x-1} - \frac{6x}{2-x^2} -\frac{1}{x} - \frac{4x}{2x^2-3}-1) \cdot \frac{(2-x^2)^3\cdot(x-1)^2}{(2x^3-3x)\cdot e^x} $$

# %% [markdown]
# __6*.__ Вывести табличное значение производной для функции
#
# ### $$\mbox{arctg}(x)$$
#
# **Решение**
#
# $$y = \mbox{arctg } x$$
#
# $$x = \mbox{tg } y$$
#
# $$y'_x = \frac{1}{x'_y} = \frac{1}{\frac{1}{\cos^2 y}} = \cos^2 (\mbox{arctg } x) = (\sqrt{\frac{1}{1+x^2}})^2 = \frac{1}{1+x^2} $$

# %% [markdown]
# __7.__ Найти длину $𝑥$ и ширину $𝑦$ прямоугольника при заданном периметре $𝑃=144$ cм, при которых данный прямоугольник имеет наибольшую площадь $𝑆$.
#
# **Решение**
#
# $$P = 2(x + y) = 144$$
#
# $$y = 72 - x$$
#
# $$S = x \cdot y = x \cdot (72-x)$$
#
# $$S'(x) = 72 - 2x $$
#
# $S'(x) = 0$ при $x = 36 $, $y = 72-36 = 36$. Прямоугольник является квадратом.

# %% [markdown]
# 8*. Завод  A  отстоит от железной дороги, идущей с юга на север и проходящей через  B , считая по кратчайшему расстоянию на  a  км. Под каким углом  α  к железной дороге следует ппостроить подъезной путь от завода, чтобы транспортировка грузов из  A  в  B  была наиболее экономичной, если стоимость провоза тонны груза на расстоянии  1  км составляет: по подъезному пути  p  рублей, по железной дороге  q  рублей  (p>q)  и город  B  расположен на  b  км севернее завода  A.
#
# **Решение**
#
# Обозначим проекцию завода на железную дорогу $H$, $S$ - место подъезда к железной дороге, угол $HSA$, под которым построен подъезд к дороге $\alpha$. Тогда $|AH| = a, |AS| = \frac{a}{\sin \alpha}, |SH| = a \cdot \mbox{ctg } \alpha, |BS| = |b - a \cdot \mbox{ctg } \alpha|$
#
# ![lesson6_task8.jpg](data:image/jpeg;base64,...)
#
# Тогда стоимость перевозки равна
#
# $$P(\alpha) = q|b - a\cdot \mbox{ctg }\alpha| + p \cdot \frac{a}{\sin \alpha}$$
#
# Возможны 2 случая
#
# 1) $b - a \cdot \mbox{ctg } \alpha > 0$:
#
# $$f'(\alpha) = - q \cdot a \frac{1}{\sin^2 \alpha} + p \cdot a \frac{\cos \alpha}{\sin^2 \alpha} = \frac{a}{\sin^2 \alpha} \cdot (p \cdot \cos \alpha - q)$$
#
# $f'(\alpha) = 0$ при $\alpha = \arccos \frac{q}{p}$. При $\alpha > \arccos \frac{q}{p} \,\,\, f'(\alpha) > 0$, при $\alpha < \arccos \frac{q}{p} \,\,\, f'(\alpha) < 0$. Таким образом, $\alpha = \arccos \frac{q}{p}$ является точкой минимума.
#
# 2) $b - a \cdot \mbox{ctg } \alpha <= 0$:
#
# $$\alpha \leqslant \mbox{arctg} \frac{b}{a}$$
#
# $$f'(\alpha) = q \cdot a \frac{1}{\sin^2 \alpha} + p \cdot a \frac{\cos \alpha}{\sin^2 \alpha} = \frac{a}{\sin^2 \alpha} \cdot (p \cdot \cos \alpha + q)$$
#
# При $\alpha \leqslant \mbox{arctg} \frac{b}{a} \,\,\, f'(\alpha) > 0 $. Значит $\alpha = \mbox{arctg} \frac{b}{a}$ является точкой минимума.
#
# Таким образом, $\alpha = \max(\arccos \frac{q}{p}, \mbox{arctg} \frac{b}{a})$
